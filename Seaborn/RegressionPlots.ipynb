# %%
import seaborn as sns
# %matplotlib inline
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## lmplot()

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex')

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',markers=['o','v'])

# %%
#scatter_kws changes size
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',markers=['o','v'],
          scatter_kws={'s':100})

# %%
#seperating the cols
sns.lmplot(x='total_bill',y='tip',data=tips,col='sex')

# %%
#seperating by rows and cols
sns.lmplot(x='total_bill',y='tip',data=tips,col='sex',row='time')

# %%
#seperating by rows and cols and hue
sns.lmplot(x='total_bill',y='tip',data=tips,col='sex',row='time',hue='day')

# %% [markdown]
# ## Changing size and aspect ratio

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='sex',row='time',hue='day',aspect=0.6,size=8)
# Out:
# C:\Users\Sumit\anaconda3\envs\cv\lib\site-packages\seaborn\regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
! git add RegressionPlots.ipynb
! git commit -m "18:50/06-06-2021"
! git push origin main
